# %%
import pandas as pd
import numpy as np 

image_array = np.load("C:\\Users\\Musae\\Documents\\GitHub-REPOs\\Senior-project_Doc\\Docs\\Array\\NDVI-Array\\NDVI_RUH-B4-B8_2018-12-15.npy")


# Convert the NumPy array to a DataFrame
df = pd.DataFrame(image_array)

# Save the DataFrame to a CSV file
csv_file_path = 'C:\\Users\\Musae\\Documents\\GitHub-REPOs\\Vegetation-Cover-In-Riyadh\\Codes\\Structring the data\\data\\NDVI_RUH_2018-12-15.csv'
df.to_csv(csv_file_path, index=False)

csv_file_path
# Out:
# 'C:\\Users\\Musae\\Documents\\GitHub-REPOs\\Vegetation-Cover-In-Riyadh\\Codes\\Structring the data\\data\\NDVI_RUH_2018-12-15.csv'

# %%
df
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.010000  0.010000  0.010000  0.010000  0.010000  0.010000  0.010000
# 1     0.010000  0.010000  0.010000  0.010000  0.010000  0.010000  0.010000
# 2     0.010000  0.010000  0.010000  0.010000  0.010000  0.010000  0.010000
# 3     0.087888  0.089372  0.088413  0.087330  0.086576  0.085039  0.087344
# 4     0.084595  0.089022  0.081478  0.080822  0.089515  0.087061  0.084080
# ...        ...       ...       ...       ...       ...       ...       ...
# 6340  0.446068  0.446068  0.376054  0.373166  0.433262  0.469472  0.546263
# 6341  0.422252  0.422252  0.367388  0.379383  0.413534  0.466759  0.550884
# 6342  0.405369  0.405369  0.387797  0.404933  0.435513  0.494109  0.577366
# 6343  0.426253  0.397113  0.397113  0.409871  0.468292  0.490734  0.627858
# 6344  0.010000  0.417811  0.417811  0.405480  0.453429  0.558372  0.677749
#
# ...
