# %%
import os
from osgeo import gdal
import numpy as np

# %%
input_folder_path = "G:\\My Drive\\Riyadh-Data-set\\RUH_Row"
output_folder_path = 'C:\\Users\\Musae\\Documents\\GitHub-REPOs\\Senior-project-main\\NDVI-data'


for filename in os.listdir(input_folder_path):
    if filename.endswith('.tif'):
        file_path = os.path.join(input_folder_path, filename)
        
        dataset = gdal.Open(file_path)
        
        if dataset is None:
            print(f"Failed to open file {filename}")
            continue
        
        # Assuming Band 4 is the first band and Band 8 is the second band in your files
        red_band = dataset.GetRasterBand(1).ReadAsArray().astype(float)
        nir_band = dataset.GetRasterBand(2).ReadAsArray().astype(float)
        
        # Calculate NDVI
        # Avoid division by zero by adding a small number to the denominator
        ndvi = (nir_band - red_band) / (nir_band + red_band + 1e-10)
        
        # Create a GDAL driver for TIF files
        driver = gdal.GetDriverByName('GTiff')
        
        # Create a new NDVI TIF file with the same size as the input image
        ndvi_dataset = driver.Create(os.path.join(output_folder_path, f'NDVI_{filename}'), red_band.shape[1], red_band.shape[0], 1, gdal.GDT_Float32)
        
        # Set NDVI image geotransform and projection from the original dataset
        ndvi_dataset.SetGeoTransform(dataset.GetGeoTransform())
        ndvi_dataset.SetProjection(dataset.GetProjection())
        
        # Write the NDVI array to the newly created TIF file
        ndvi_dataset.GetRasterBand(1).WriteArray(ndvi)
        
        # Close the datasets
        ndvi_dataset = None
        dataset = None

        print(f"NDVI image saved for {filename}")
# Out:
# c:\Users\Musae\AppData\Local\Programs\Python\Python311\Lib\site-packages\osgeo\gdal.py:312: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# NDVI image saved for RUH-B4-B8_2018-12-15.tif
# NDVI image saved for RUH-B4-B8_2019-02-13.tif
# NDVI image saved for RUH-B4-B8_2019-01-14.tif
# NDVI image saved for RUH-B4-B8_2019-03-15.tif
# NDVI image saved for RUH-B4-B8_2019-04-14.tif
# NDVI image saved for RUH-B4-B8_2019-05-14.tif
# NDVI image saved for RUH-B4-B8_2019-06-13.tif
# NDVI image saved for RUH-B4-B8_2019-07-13.tif
# NDVI image saved for RUH-B4-B8_2019-08-12.tif
# NDVI image saved for RUH-B4-B8_2019-09-11.tif
# NDVI image saved for RUH-B4-B8_2019-10-11.tif
# NDVI image saved for RUH-B4-B8_2019-11-10.tif
# NDVI image saved for RUH-B4-B8_2019-12-10.tif
# NDVI image saved for RUH-B4-B8_2020-01-09.tif
# NDVI image saved for RUH-B4-B8_2020-03-09.tif
# NDVI image saved for RUH-B4-B8_2020-02-08.tif
# NDVI image saved for RUH-B4-B8_2020-04-08.tif
# NDVI image saved for RUH-B4-B8_2020-05-08.tif
# NDVI image saved for RUH-B4-B8_2020-08-06.tif
# NDVI image saved for RUH-B4-B8_2020-07-07.tif
# NDVI image saved for RUH-B4-B8_2020-06-07.tif
# NDVI image saved for RUH-B4-B8_2020-09-05.tif
# NDVI image saved for RUH-B4-B8_2020-10-05.tif
# NDVI image saved for RUH-B4-B8_2020-11-04.tif
# NDVI image saved for RUH-B4-B8_2020-12-04.tif
# NDVI image saved for RUH-B4-B8_2021-01-03.tif
# NDVI image saved for RUH-B4-B8_2021-04-03.tif
# NDVI image saved for RUH-B4-B8_2021-03-04.tif
# NDVI image saved for RUH-B4-B8_2021-02-02.tif
# NDVI image saved for RUH-B4-B8_2021-07-02.tif
# NDVI image saved for RUH-B4-B8_2021-05-03.tif
# NDVI image saved for RUH-B4-B8_2021-06-02.tif
# NDVI image saved for RUH-B4-B8_2021-08-31.tif
# NDVI image saved for RUH-B4-B8_2021-08-01.tif
# NDVI image saved for RUH-B4-B8_2021-09-30.tif
# NDVI image saved for RUH-B4-B8_2021-11-29.tif
# NDVI image saved for RUH-B4-B8_2021-10-30.tif
# NDVI image saved for RUH-B4-B8_2021-12-29.tif
# NDVI image saved for RUH-B4-B8_2022-01-28.tif
# NDVI image saved for RUH-B4-B8_2022-02-27.tif
# NDVI image saved for RUH-B4-B8_2022-04-28.tif
# NDVI image saved for RUH-B4-B8_2022-05-28.tif
# NDVI image saved for RUH-B4-B8_2022-06-27.tif
# NDVI image saved for RUH-B4-B8_2022-07-27.tif
# NDVI image saved for RUH-B4-B8_2022-08-26.tif
# NDVI image saved for RUH-B4-B8_2022-09-25.tif
# NDVI image saved for RUH-B4-B8_2022-10-25.tif
# NDVI image saved for RUH-B4-B8_2023-01-23.tif
# NDVI image saved for RUH-B4-B8_2022-11-24.tif
# NDVI image saved for RUH-B4-B8_2023-03-24.tif
# NDVI image saved for RUH-B4-B8_2023-02-22.tif
# NDVI image saved for RUH-B4-B8_2023-04-23.tif
# NDVI image saved for RUH-B4-B8_2023-05-23.tif
# NDVI image saved for RUH-B4-B8_2023-06-22.tif
# NDVI image saved for RUH-B4-B8_2023-07-22.tif
# NDVI image saved for RUH-B4-B8_2023-08-21.tif
# NDVI image saved for RUH-B4-B8_2023-09-20.tif
# NDVI image saved for RUH-B4-B8_2023-10-20.tif
# NDVI image saved for RUH-B4-B8_2023-11-19.tif
# NDVI image saved for RUH-B4-B8_2023-12-19.tif
